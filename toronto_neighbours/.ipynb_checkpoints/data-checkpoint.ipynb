# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

#!conda install -c conda-forge geopy --yes
from geopy.geocoders import Nominatim
import urllib.request
import json
from bs4 import BeautifulSoup
from urllib.request import urlopen
import requests
from pandas.io.json import json_normalize

import matplotlib.cm as cm
import matplotlib.colors as colors
# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.pyplot as plt
import matplotlib.colors as colors
# %matplotlib inline
from sklearn.cluster import KMeans

#!conda install -c conda-forge folium=0.5.0 --yes
import folium
from folium import plugins

print('Libraries imported.')
# Out:
# Libraries imported.

# %%
CLIENT_ID = 'VVDNPACN2HTRYWPH3WKWLSPYKJHLBFMY2QB2EDSC5POCTUSL' # your Foursquare ID
CLIENT_SECRET = 'OVLLVEMZW4SZF5ESVTDBW3FKTW1IW15ZLORCUTAFDM0IXQVO' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 40
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: VVDNPACN2HTRYWPH3WKWLSPYKJHLBFMY2QB2EDSC5POCTUSL
# CLIENT_SECRET:OVLLVEMZW4SZF5ESVTDBW3FKTW1IW15ZLORCUTAFDM0IXQVO

# %%
request_parameters = {
    "client_id": CLIENT_ID,
    "client_secret": CLIENT_SECRET,
    "v": '20180605',
    "section": "coffee",
    "near": "los angeles",
    "radius": 1000,
    "limit": 50}

data = requests.get("https://api.foursquare.com/v2/venues/explore", params=request_parameters)

# %%
d = data.json()["response"]
d.keys()
# Out:
# dict_keys(['suggestedFilters', 'geocode', 'headerLocation', 'headerFullLocation', 'headerLocationGranularity', 'query', 'totalResults', 'suggestedBounds', 'groups'])

# %% [markdown]
# find coffee shops and associated metadata

# %%
items = d["groups"][0]["items"]
print("number of items: %i" % len(items))
items[0]
# Out:
# number of items: 50
# {'reasons': {'count': 0,
#   'items': [{'summary': 'This spot is popular',
#     'type': 'general',
#     'reasonName': 'globalInteractionReason'}]},
#  'venue': {'id': '4e2071738130e92fc6a3f821',
#   'name': 'Cafe Demitasse',
#   'location': {'address': '135 S San Pedro St',
#    'crossStreet': 'at 2nd St',
#    'lat': 34.04966845839441,
#    'lng': -118.24169634169901,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 34.04966845839441,
#      'lng': -118.24169634169901},
#     {'label': 'entrance', 'lat': 34.049761, 'lng': -118.241609}],
#    'postalCode': '90012',
#    'cc': 'US',
#    'city': 'Los Angeles',
#    'state': 'CA',
#    'country': 'United States',
#    'formattedAddress': ['135 S San Pedro St (at 2nd St)',
#     'Los Angeles, CA 90012',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d1e0931735',
#     'name': 'Coffee Shop',
#     'pluralName': 'Coffee Shops',
#     'shortName': 'Coffee Shop',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#      'suffix': '.png'},
#     'primary': True}],
#   'photos': {'count': 0, 'groups': []}},
#  'referralId': 'e-5-4e2071738130e92fc6a3f821-0'}

# %%
df_raw = []
for item in items:
    venue = item["venue"]
    categories, uid, name, location = venue["categories"], venue["id"], venue["name"], venue["location"]
    print(location)
    assert len(categories) == 1
    shortname = categories[0]["shortName"]
    address =  ''
    if hasattr(location, 'address'):
      address = location['address']
    if not "postalCode" in location:
        continue
    postalcode = location["postalCode"]
    lat = location["lat"]
    lng = location["lng"]
    datarow = (uid, name, shortname, address, postalcode, lat, lng)
    df_raw.append(datarow)
df = pd.DataFrame(df_raw, columns=["uid", "name", "shortname", "address", "postalcode", "lat", "lng"])
print("found %i cafes" % len(df))
df.head()
# Out:
# {'address': '135 S San Pedro St', 'crossStreet': 'at 2nd St', 'lat': 34.04966845839441, 'lng': -118.24169634169901, 'labeledLatLngs': [{'label': 'display', 'lat': 34.04966845839441, 'lng': -118.24169634169901}, {'label': 'entrance', 'lat': 34.049761, 'lng': -118.241609}], 'postalCode': '90012', 'cc': 'US', 'city': 'Los Angeles', 'state': 'CA', 'country': 'United States', 'formattedAddress': ['135 S San Pedro St (at 2nd St)', 'Los Angeles, CA 90012', 'United States']}
# {'address': '116 Judge John Aiso St', 'lat': 34.0509079511909, 'lng': -118.240436223769, 'labeledLatLngs': [{'label': 'display', 'lat': 34.0509079511909, 'lng': -118.240436223769}], 'postalCode': '90012', 'cc': 'US', 'city': 'Los Angeles', 'state': 'CA', 'country': 'United States', 'formattedAddress': ['116 Judge John Aiso St', 'Los Angeles, CA 90012', 'United States']}
# {'address': '304 S Broadway', 'lat': 34.050881374258196, 'lng': -118.24795177127038, 'labeledLatLngs': [{'label': 'display', 'lat': 34.050881374258196, 'lng': -118.24795177127038}], 'postalCode': '90013', 'cc': 'US', 'city': 'Los Angeles', 'state': 'CA', 'country': 'United States', 'formattedAddress': ['304 S Broadway', 'Los Angeles, CA 90013', 'United States']}
# {'address': '134 Japanese Village Plaza Mall Bldg E', 'lat': 34.0488687598013, 'lng': -118.24050832309565, 'labeledLatLngs': [{'label': 'display', 'lat': 34.0488687598013, 'lng': -118.24050832309565}, {'label': 'entrance', 'lat': 34.048856, 'lng': -118.240254}], 'postalCode': '90012', 'cc': 'US', 'city': 'Los Angeles', 'state': 'CA', 'country': 'United States', 'formattedAddress': ['134 Japanese Village Plaza Mall Bldg E', 'Los Angeles, CA 90012', 'United States']}
# {'address': '334 S Main St Kiosk #1', 'lat': 34.048257781985086, 'lng': -118.24635856537913, 'labeledLatLngs': [{'label': 'display', 'lat': 34.048257781985086, 'lng': -118.24635856537913}], 'postalCode': '90013', 'cc': 'US', 'city': 'Los Angeles', 'state': 'CA', 'country': 'United States', 'formattedAddress': ['334 S Main St Kiosk #1', 'Los Angeles, CA 90013', 'United States']}
# {'address': '324 S Hill St #C19', 'crossStreet': 'btwn 3rd & 4th St', 'lat': 34.0510057154355, 'lng': -118.24935561622416, 'labeledLatLngs': [{'label': 'display', 'lat': 34.0510057154355, 'lng': -118.24935561622416}], 'postalCode': '90013', 'cc': 'US', 'city': 'Los Angeles', 'state': 'CA', 'country': 'United States', 'formattedAddress': ['324 S Hill St #C19 (btwn 3rd & 4th St)', 'Los Angeles, CA 90013', 'United States']}
# {'address': '232 East 2nd Street', 'lat': 34.049518247264665, 'lng': -118.24190789611599, 'labeledLatLngs': [{'label': 'display', 'lat': 34.049518247264665, 'lng': -118.24190789611599}], 'postalCode': '90012', 'cc': 'US', 'city': 'Los Angeles', 'state': 'CA', 'country': 'United States', 'formattedAddress': ['232 East 2nd Street', 'Los Angeles, CA 90012', 'United States']}
# {'address': '117 Japanese Village Plaza Mall', 'crossStreet': 'at E 1st St', 'lat': 34.04895851153433, 'lng': -118.24000092940908, 'labeledLatLngs': [{'label': 'display', 'lat': 34.04895851153433, 'lng': -118.24000092940908}, {'label': 'entrance', 'lat': 34.049052, 'lng': -118.239952}], 'postalCode': '90012', 'cc': 'US', 'city': 'Los Angeles', 'state': 'CA', 'country': 'United States', 'formattedAddress': ['117 Japanese Village Plaza Mall (at E 1st St)', 'Los Angeles, CA 90012', 'United States']}
# {'address': '413 S Main St', 'crossStreet': 'btwn E 4th & Winston St', 'lat': 34.047693182816566, 'lng': -118.24753187315073, 'labeledLatLngs': [{'label': 'display', 'lat': 34.047693182816566, 'lng': -118.24753187315073}], 'postalCode': '90013', 'cc': 'US', 'city': 'Los Angeles', 'state': 'CA', 'country': 'United States', 'formattedAddress': ['413 S Main St (btwn E 4th & Winston St)', 'Los Angeles, CA 90013', 'United States']}
# {'address': '358 E 2nd St', 'lat': 34.04818435932437, 'lng': -118.24011529415962, 'labeledLatLngs': [{'label': 'display', 'lat': 34.04818435932437, 'lng': -118.24011529415962}, {'label': 'entrance', 'lat': 34.048101, 'lng': -118.240056}], 'postalCode': '90012', 'cc': 'US', 'city': 'Los Angeles', 'state': 'CA', 'country': 'United States', 'formattedAddress': ['358 E 2nd St', 'Los Angeles, CA 90012', 'United States']}
# {'address': '330 E 2nd St Ste C', 'lat': 34.04859018014104, 'lng': -118.24094069851323, 'labeledLatLngs': [{'label': 'display', 'lat': 34.04859018014104, 'lng': -118.24094069851323}], 'postalCode': '90012', 'cc': 'US', 'city': 'Los Angeles', 'state': 'CA', 'country': 'United States', 'formattedAddress': ['330 E 2nd St Ste C', 'Los Angeles, CA 90012', 'United States']}
# {'address': '200 N Spring St', 'crossStreet': '2nd Floor City Hall', 'lat': 34.05347097170739, 'lng': -118.24227856718933, 'labeledLatLngs': [{'label': 'display', 'lat': 34.05347097170739, 'lng': -118.24227856718933}], 'postalCode': '90012', 'cc': 'US', 'city': 'Los Angeles', 'state': 'CA', 'country': 'United States', 'formattedAddress': ['200 N Spring St (2nd Floor City Hall)', 'Los Angeles, CA 90012', 'United States']}
# {'address': '12 Olvera St', 'lat': 34.05751836354504, 'lng': -118.23752579067191, 'labeledLatLngs': [{'label': 'display', 'lat': 34.05751836354504, 'lng': -118.23752579067191}], 'postalCode': '90012', 'cc': 'US', 'city': 'Los Angeles', 'state': 'CA', 'country': 'United States', 'formattedAddress': ['12 Olvera St', 'Los Angeles, CA 90012', 'United States']}
# {'address': '543 S Broadway', 'crossStreet': 'Sixth Street', 'lat': 34.04723, 'lng': -118.25198700000001, 'labeledLatLngs': [{'label': 'display', 'lat': 34.04723, 'lng': -118.25198700000001}, {'label': 'entrance', 'lat': 34.047125, 'lng': -118.251773}], 'postalCode': '90013', 'cc': 'US', 'city': 'Los Angeles', 'state': 'CA', 'country': 'United States', 'formattedAddress': ['543 S Broadway (Sixth Street)', 'Los Angeles, CA 90013', 'United States']}
# {'address': '710 E 4th Pl', 'crossStreet': 'Alameda', 'lat': 34.04516352947767, 'lng': -118.23772399287017, 'labeledLatLngs': [{'label': 'display', 'lat': 34.04516352947767, 'lng': -118.23772399287017}], 'postalCode': '90013', 'cc': 'US', 'city': 'Los Angeles', 'state': 'CA', 'country': 'United States', 'formattedAddress': ['710 E 4th Pl (Alameda)', 'Los Angeles, CA 90013', 'United States']}
# {'address': '601 W 5th St', 'lat': 34.050547, 'lng': -118.254062, 'labeledLatLngs': [{'label': 'display', 'lat': 34.050547, 'lng': -118.254062}], 'postalCode': '90071', 'cc': 'US', 'city': 'Los Angeles', 'state': 'CA', 'country': 'United States', 'formattedAddress': ['601 W 5th St', 'Los Angeles, CA 90071', 'United States']}
# {'address': '548 S Spring St #106', 'crossStreet': 'at W 6th St', 'lat': 34.04621028894699, 'lng': -118.25074774064137, 'labeledLatLngs': [{'label': 'display', 'lat': 34.04621028894699, 'lng': -118.25074774064137}], 'postalCode': '90013', 'cc': 'US', 'city': 'Los Angeles', 'state': 'CA', 'country': 'United States', 'formattedAddress': ['548 S Spring St #106 (at W 6th St)', 'Los Angeles, CA 90013', 'United States']}
# {'address': 'California Plaza', 'lat': 34.05292207428664, 'lng': -118.24789695677013, 'labeledLatLngs': [{'label': 'display', 'lat': 34.05292207428664, 'lng': -118.24789695677013}], 'postalCode': '90012', 'cc': 'US', 'city': 'Los Angeles', 'state': 'CA', 'country': 'United States', 'formattedAddress': ['California Plaza', 'Los Angeles, CA 90012', 'United States']}
# {'address': '111 S Grand Ave', 'lat': 34.055414111883145, 'lng': -118.24931868069875, 'labeledLatLngs': [{'label': 'display', 'lat': 34.055414111883145, 'lng': -118.24931868069875}], 'postalCode': '90012', 'cc': 'US', 'city': 'Los Angeles', 'state': 'CA', 'country': 'United States', 'formattedAddress': ['111 S Grand Ave', 'Los Angeles, CA 90012', 'United States']}
# {'address': '343 Broadway', 'crossStreet': '4th Street', 'lat': 34.04978, 'lng': -118.249185, 'labeledLatLngs': [{'label': 'display', 'lat': 34.04978, 'lng': -118.249185}], 'postalCode': '90013', 'cc': 'US', 'city': 'Los Angeles', 'state': 'CA', 'country': 'United States', 'formattedAddress': ['343 Broadway (4th Street)', 'Los Angeles, CA 90013', 'United States']}
# {'address': '400 S Main St', 'crossStreet': 'at E 4th St', 'lat': 34.04799696524164, 'lng': -118.2472014427185, 'postalCode': '90013', 'cc': 'US', 'city': 'Los Angeles', 'state': 'CA', 'country': 'United States', 'formattedAddress': ['400 S Main St (at E 4th St)', 'Los Angeles, CA 90013', 'United States']}
# {'address': '120 S Los Angeles St', 'lat': 34.051131284951325, 'lng': -118.24230179688826, 'labeledLatLngs': [{'label': 'display', 'lat': 34.051131284951325, 'lng': -118.24230179688826}, {'label': 'entrance', 'lat': 34.050637, 'lng': -118.242835}], 'postalCode': '90012', 'cc': 'US', 'city': 'Los Angeles', 'state': 'CA', 'country': 'United States', 'formattedAddress': ['120 S Los Angeles St', 'Los Angeles, CA 90012', 'United States']}
# {'address': '450 E 2nd St', 'lat': 34.0470848, 'lng': -118.2385981, 'labeledLatLngs': [{'label': 'display', 'lat': 34.0470848, 'lng': -118.2385981}, {'label': 'entrance', 'lat': 34.047047, 'lng': -118.238702}], 'postalCode': '90012', 'cc': 'US', 'city': 'Los Angeles', 'state': 'CA', 'country': 'United States', 'formattedAddress': ['450 E 2nd St', 'Los Angeles, CA 90012', 'United States']}
# {'address': '330 S Hope St', 'lat': 34.05291981007566, 'lng': -118.25274047202105, 'labeledLatLngs': [{'label': 'display', 'lat': 34.05291981007566, 'lng': -118.25274047202105}], 'postalCode': '90071', 'cc': 'US', 'city': 'Los Angeles', 'state': 'CA', 'country': 'United States', 'formattedAddress': ['330 S Hope St', 'Los Angeles, CA 90071', 'United States']}
# {'address': '217 N Hill St', 'lat': 34.05629593934089, 'lng': -118.24702241897303, 'labeledLatLngs': [{'label': 'display', 'lat': 34.05629593934089, 'lng': -118.24702241897303}], 'postalCode': '90012', 'cc': 'US', 'city': 'Los Angeles', 'state': 'CA', 'country': 'United States', 'formattedAddress': ['217 N Hill St', 'Los Angeles, CA 90012', 'United States']}
# {'address': '541 S Spring St', 'lat': 34.04679351872283, 'lng': -118.25112642918464, 'labeledLatLngs': [{'label': 'display', 'lat': 34.04679351872283, 'lng': -118.25112642918464}], 'postalCode': '90013', 'cc': 'US', 'city': 'Los Angeles', 'state': 'CA', 'country': 'United States', 'formattedAddress': ['541 S Spring St', 'Los Angeles, CA 90013', 'United States']}
# {'address': '3rd Street', 'crossStreet': 'Alameda Street', 'lat': 34.045381, 'lng': -118.238306, 'labeledLatLngs': [{'label': 'display', 'lat': 34.045381, 'lng': -118.238306}], 'postalCode': '90013', 'cc': 'US', 'city': 'Los Angeles', 'state': 'CA', 'country': 'United States', 'formattedAddress': ['3rd Street (Alameda Street)', 'Los Angeles, CA 90013', 'United States']}
# {'address': '506 S. Grand Avenue', 'crossStreet': '5th & Olive', 'lat': 34.04908997979816, 'lng': -118.25322536780875, 'labeledLatLngs': [{'label': 'display', 'lat': 34.04908997979816, 'lng': -118.25322536780875}], 'postalCode': '90071', 'cc': 'US', 'city': 'Los Angeles', 'state': 'CA', 'country': 'United States', 'formattedAddress': ['506 S. Grand Avenue (5th & Olive)', 'Los Angeles, CA 90071', 'United States']}
# {'address': '369 E 2nd St', 'lat': 34.04817245387403, 'lng': -118.2400524649392, 'labeledLatLngs': [{'label': 'display', 'lat': 34.04817245387403, 'lng': -118.2400524649392}, {'label': 'entrance', 'lat': 34.048194, 'lng': -118.239876}], 'postalCode': '90012', 'cc': 'US', 'city': 'Los Angeles', 'state': 'CA', 'country': 'United States', 'formattedAddress': ['369 E 2nd St', 'Los Angeles, CA 90012', 'United States']}
# {'address': '116 E 5th St', 'crossStreet': 'btwn S Main St & S Los Angeles St', 'lat': 34.046109, 'lng': -118.248098, 'labeledLatLngs': [{'label': 'display', 'lat': 34.046109, 'lng': -118.248098}], 'postalCode': '90013', 'cc': 'US', 'city': 'Los Angeles', 'state': 'CA', 'country': 'United States', 'formattedAddress': ['116 E 5th St (btwn S Main St & S Los Angeles St)', 'Los Angeles, CA 90013', 'United States']}
# {'address': '333 S Spring St', 'crossStreet': '3rd Street', 'lat': 34.04969468182012, 'lng': -118.24779987825168, 'labeledLatLngs': [{'label': 'display', 'lat': 34.04969468182012, 'lng': -118.24779987825168}, {'label': 'entrance', 'lat': 34.04949, 'lng': -118.247876}], 'postalCode': '90013', 'cc': 'US', 'city': 'Los Angeles', 'state': 'CA', 'country': 'United States', 'formattedAddress': ['333 S Spring St (3rd Street)', 'Los Angeles, CA 90013', 'United States']}
# {'address': '453 S Spring St Fl 9', 'crossStreet': 'at 5th St', 'lat': 34.047709061184435, 'lng': -118.24943226958771, 'labeledLatLngs': [{'label': 'display', 'lat': 34.047709061184435, 'lng': -118.24943226958771}], 'postalCode': '90013', 'cc': 'US', 'city': 'Los Angeles', 'state': 'CA', 'country': 'United States', 'formattedAddress': ['453 S Spring St Fl 9 (at 5th St)', 'Los Angeles, CA 90013', 'United States']}
# {'address': '200 S Grand Ave', 'lat': 34.053756385586404, 'lng': -118.24963845950508, 'labeledLatLngs': [{'label': 'display', 'lat': 34.053756385586404, 'lng': -118.24963845950508}], 'postalCode': '90012', 'cc': 'US', 'city': 'Los Angeles', 'state': 'CA', 'country': 'United States', 'formattedAddress': ['200 S Grand Ave', 'Los Angeles, CA 90012', 'United States']}
# {'address': '11111 Santa Monica Blvd', 'lat': 34.05534801448067, 'lng': -118.24922911238244, 'labeledLatLngs': [{'label': 'display', 'lat': 34.05534801448067, 'lng': -118.24922911238244}], 'postalCode': '90025', 'cc': 'US', 'city': 'Los Angeles', 'state': 'CA', 'country': 'United States', 'formattedAddress': ['11111 Santa Monica Blvd', 'Los Angeles, CA 90025', 'United States']}
# {'address': '330 S Hope St', 'lat': 34.052720943791286, 'lng': -118.2524918113982, 'labeledLatLngs': [{'label': 'display', 'lat': 34.052720943791286, 'lng': -118.2524918113982}], 'postalCode': '90071', 'cc': 'US', 'city': 'Los Angeles', 'state': 'CA', 'country': 'United States', 'formattedAddress': ['330 S Hope St', 'Los Angeles, CA 90071', 'United States']}
# {'address': '400 S Hope St', 'crossStreet': '4th Street', 'lat': 34.05182132874913, 'lng': -118.25339196103394, 'labeledLatLngs': [{'label': 'display', 'lat': 34.05182132874913, 'lng': -118.25339196103394}], 'postalCode': '90071', 'cc': 'US', 'neighborhood': 'Financial District', 'city': 'Los Angeles', 'state': 'CA', 'country': 'United States', 'formattedAddress': ['400 S Hope St (4th Street)', 'Los Angeles, CA 90071', 'United States']}
# {'address': '127 E 6th St', 'lat': 34.04482482583459, 'lng': -118.24929991598584, 'labeledLatLngs': [{'label': 'display', 'lat': 34.04482482583459, 'lng': -118.24929991598584}], 'postalCode': '90014', 'cc': 'US', 'city': 'Los Angeles', 'state': 'CA', 'country': 'United States', 'formattedAddress': ['127 E 6th St', 'Los Angeles, CA 90014', 'United States']}
# {'lat': 34.05320077941401, 'lng': -118.25166151209613, 'labeledLatLngs': [{'label': 'display', 'lat': 34.05320077941401, 'lng': -118.25166151209613}], 'postalCode': '90071', 'cc': 'US', 'city': 'Los Angeles', 'state': 'CA', 'country': 'United States', 'formattedAddress': ['Los Angeles, CA 90071', 'United States']}
# {'address': '100 S Main St', 'crossStreet': '1st', 'lat': 34.05196842646788, 'lng': -118.24337494390313, 'labeledLatLngs': [{'label': 'display', 'lat': 34.05196842646788, 'lng': -118.24337494390313}], 'postalCode': '90012', 'cc': 'US', 'city': 'Los Angeles', 'state': 'CA', 'country': 'United States', 'formattedAddress': ['100 S Main St (1st)', 'Los Angeles, CA 90012', 'United States']}
# {'address': '123 Astronaut ellison S E onizuka st. Ste 101-D', 'lat': 34.05002, 'lng': -118.242165, 'labeledLatLngs': [{'label': 'display', 'lat': 34.05002, 'lng': -118.242165}], 'postalCode': '90012', 'cc': 'US', 'city': 'Los Angeles', 'state': 'CA', 'country': 'United States', 'formattedAddress': ['123 Astronaut ellison S E onizuka st. Ste 101-D', 'Los Angeles, CA 90012', 'United States']}
# {'address': '333 S Alameda St', 'lat': 34.04549972535548, 'lng': -118.2383337295066, 'labeledLatLngs': [{'label': 'display', 'lat': 34.04549972535548, 'lng': -118.2383337295066}], 'postalCode': '90013', 'cc': 'US', 'city': 'Los Angeles', 'state': 'CA', 'country': 'United States', 'formattedAddress': ['333 S Alameda St', 'Los Angeles, CA 90013', 'United States']}
# {'address': '306 W 2nd St', 'lat': 34.052490999999996, 'lng': -118.247134, 'labeledLatLngs': [{'label': 'display', 'lat': 34.052490999999996, 'lng': -118.247134}, {'label': 'entrance', 'lat': 34.052564, 'lng': -118.247095}], 'postalCode': '90012', 'cc': 'US', 'city': 'Los Angeles', 'state': 'CA', 'country': 'United States', 'formattedAddress': ['306 W 2nd St', 'Los Angeles, CA 90012', 'United States']}
# {'address': '331 E 1st St', 'lat': 34.049785167076834, 'lng': -118.24011940605794, 'labeledLatLngs': [{'label': 'display', 'lat': 34.049785167076834, 'lng': -118.24011940605794}], 'postalCode': '90012', 'cc': 'US', 'city': 'Los Angeles', 'state': 'CA', 'country': 'United States', 'formattedAddress': ['331 E 1st St', 'Los Angeles, CA 90012', 'United States']}
# {'address': '328 E 1st St', 'lat': 34.04985765517114, 'lng': -118.24002199881568, 'labeledLatLngs': [{'label': 'display', 'lat': 34.04985765517114, 'lng': -118.24002199881568}], 'postalCode': '90012', 'cc': 'US', 'city': 'Los Angeles', 'state': 'CA', 'country': 'United States', 'formattedAddress': ['328 E 1st St', 'Los Angeles, CA 90012', 'United States']}
# {'address': '339 E 1st St', 'lat': 34.04977035522461, 'lng': -118.23976135253906, 'labeledLatLngs': [{'label': 'display', 'lat': 34.04977035522461, 'lng': -118.23976135253906}], 'postalCode': '90012', 'cc': 'US', 'city': 'Los Angeles', 'state': 'CA', 'country': 'United States', 'formattedAddress': ['339 E 1st St', 'Los Angeles, CA 90012', 'United States']}
# {'address': 'Hall of Administration', 'lat': 34.056289, 'lng': -118.24515, 'labeledLatLngs': [{'label': 'display', 'lat': 34.056289, 'lng': -118.24515}], 'postalCode': '90012', 'cc': 'US', 'city': 'Los Angeles', 'state': 'CA', 'country': 'United States', 'formattedAddress': ['Hall of Administration', 'Los Angeles, CA 90012', 'United States']}
# {'address': 'Grand Central Market, 317 S Broadway, Los Angeles, CA 90013', 'lat': 34.05055765451316, 'lng': -118.24853082089868, 'labeledLatLngs': [{'label': 'display', 'lat': 34.05055765451316, 'lng': -118.24853082089868}, {'label': 'entrance', 'lat': 34.050627, 'lng': -118.248521}], 'postalCode': '90013', 'cc': 'US', 'city': 'Los Angeles', 'state': 'CA', 'country': 'United States', 'formattedAddress': ['Grand Central Market, 317 S Broadway, Los Angeles, CA 90013', 'Los Angeles, CA 90013', 'United States']}
# {'address': '201 N Los Angeles St', 'crossStreet': 'Los Angeles', 'lat': 34.05439929613459, 'lng': -118.24079130790028, 'labeledLatLngs': [{'label': 'display', 'lat': 34.05439929613459, 'lng': -118.24079130790028}], 'postalCode': '90012', 'cc': 'US', 'city': 'Los Angeles', 'state': 'CA', 'country': 'United States', 'formattedAddress': ['201 N Los Angeles St (Los Angeles)', 'Los Angeles, CA 90012', 'United States']}
# {'address': '269 S San Pedro St', 'crossStreet': '3rd Street', 'lat': 34.04767990112305, 'lng': -118.24270629882812, 'labeledLatLngs': [{'label': 'display', 'lat': 34.04767990112305, 'lng': -118.24270629882812}], 'postalCode': '90012', 'cc': 'US', 'city': 'Los Angeles', 'state': 'CA', 'country': 'United States', 'formattedAddress': ['269 S San Pedro St (3rd Street)', 'Los Angeles, CA 90012', 'United States']}
# {'address': '369 E 1st St', 'crossStreet': 'Alameda', 'lat': 34.049653, 'lng': -118.238583, 'labeledLatLngs': [{'label': 'display', 'lat': 34.049653, 'lng': -118.238583}, {'label': 'entrance', 'lat': 34.049266, 'lng': -118.238712}], 'postalCode': '90012', 'cc': 'US', 'city': 'Los Angeles', 'state': 'CA', 'country': 'United States', 'formattedAddress': ['369 E 1st St (Alameda)', 'Los Angeles, CA 90012', 'United States']}
# found 50 cafes
#                         uid                name    shortname address  \
# 0  4e2071738130e92fc6a3f821      Cafe Demitasse  Coffee Shop
# 1  51dccd46498e4f9ac4865270           JiST Cafe    Breakfast
# 2  58680bee9c439d2cc839d367  Blue Bottle Coffee  Coffee Shop
# 3  4da117b2bf22a143f96894f8          Café Dulcé       Bakery
# 4  5856f788158b966de017c324         Tilt Coffee  Coffee Shop
#
#   postalcode        lat         lng
# 0      90012  34.049668 -118.241696
# 1      90012  34.050908 -118.240436
# 2      90013  34.050881 -118.247952
# 3      90012  34.048869 -118.240508
# 4      90013  34.048258 -118.246359

# %%
la_center = d["geocode"]
la_center
# Out:
# {'what': '',
#  'where': 'los angeles',
#  'center': {'lat': 34.05223, 'lng': -118.24368},
#  'displayString': 'Los Angeles, CA, United States',
#  'cc': 'US',
#  'geometry': {'bounds': {'ne': {'lat': 34.337306, 'lng': -118.155289},
#    'sw': {'lat': 33.703652, 'lng': -118.668176}}},
#  'slug': 'los-angeles-california',
#  'longId': '72057594043296297'}

# %%
from folium import plugins


map_la = folium.Map(location=[35.05223, -135.24368], zoom_start=14)

def add_markers(df):
    for (j, row) in df.iterrows():
        label = folium.Popup(row["name"], parse_html=True)
        folium.CircleMarker(
            [row["lat"], row["lng"]],
            radius=5,
            popup=label,
            color='red',
            fill=True,
            fill_color='#3186cc',
            fill_opacity=0.7,
            parse_html=False).add_to(map_la)

add_markers(df)
hm_data = df[["lat", "lng"]].to_numpy().tolist()
map_la.add_child(plugins.HeatMap(hm_data))

map_la
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_00aee4e2f9bf46a0853df30fdfbfc31a%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium%40master/folium/templates/leaflet_heat.min.js%22%3E%3C/script%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_00aee4e2f9bf46a0853df30fdfbfc31a%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_00aee4e2f9bf46a0853df30fdfbfc31a%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_00aee4e2f9bf46a0853df30fdfbfc31a%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%2 ...
